# %% [markdown]
# # Hierarchical clustering with 2D toy datasets
# ***
# - 將階層式聚類套用在 2D 樣板資料上, 來觀察幾種不同參數的結果有何不同

# %%
# 載入套件
import time
import warnings

import numpy as np
import matplotlib.pyplot as plt

from sklearn import cluster, datasets
from sklearn.preprocessing import StandardScaler
from itertools import cycle, islice

# %matplotlib inline

# %%
# 設定 2D 樣板資料
n_samples = 1500
random_state = 100

noisy_moons = datasets.make_moons(n_samples=n_samples, noise=.05)
blobs = datasets.make_blobs(n_samples=n_samples, random_state=8)
no_structure = np.random.rand(n_samples, 2), None

# %%
#-- old other toy dataset
noisy_circles = datasets.make_circles(n_samples=n_samples, factor=.5, noise=.05)

# Anisotropicly distributed data
X, y = datasets.make_blobs(n_samples=n_samples, random_state=random_state)
transformation = [[0.6, -0.6], [-0.4, 0.8]]
X_aniso = np.dot(X, transformation)
aniso = (X_aniso, y)

# blobs with varied variances
varied = datasets.make_blobs(n_samples=n_samples, cluster_std=[1.0, 2.5, 0.5], random_state=random_state)

# %%
# 設定群集與繪圖參數

plt.figure(figsize=(6, 6))

plot_num = 1
default_base = {'n_neighbors': 10, 'n_clusters': 3}
#datasets = [(noisy_moons, {'n_clusters': 2}), (blobs, {}), (no_structure, {})]
datasets = [(noisy_moons, {'n_clusters': 2}), (blobs, {}), (no_structure, {}),
            (noisy_circles, {'n_clusters': 2}), (varied, {'n_neighbors': 2}), (aniso, {'n_neighbors': 2})]

# %% [markdown]
# # 作業
# * 試著完成剩下三種 2D 樣板資料的繪圖, 並觀察有何不同

# %%
fig, axes = plt.subplots(len(datasets), 3, figsize=(15, 25))
plt.subplots_adjust(left=None, bottom=None, right=None, top=None, wspace=0.9, hspace=0.9)

# 執行各種樣板資料的繪圖迴圈
for i_dataset, (dataset, algo_params) in enumerate(datasets):
    i = i_dataset
    
    # 複製參數與標準化
    params = default_base.copy()
    params.update(algo_params)    
    X, y = dataset
    X = StandardScaler().fit_transform(X)

    # 設定三種不同參數的 Hierarchical clustering
    ward = cluster.AgglomerativeClustering(n_clusters=params['n_clusters'], linkage="ward")
    complete = cluster.AgglomerativeClustering(n_clusters=params['n_clusters'], linkage="complete")
    average = cluster.AgglomerativeClustering(n_clusters=params['n_clusters'], linkage="average")
    clustering_algorithms = (
        ('Average Linkage', average),
        ('Complete Linkage', complete),
        ('Ward Linkage', ward))

    # 繪製三種圖形
    for (j, (name, algorithm)) in enumerate(clustering_algorithms):
        # t0 / t1 : 紀錄時間差
        t0 = time.time()
        algorithm.fit(X)
        t1 = time.time()
        if hasattr(algorithm, 'labels_'):
            y_pred = algorithm.labels_.astype(np.int)
        else:
            y_pred = algorithm.predict(X)

        #plt.subplot(len(datasets), len(clustering_algorithms), plot_num)
        
        if i_dataset == 0:
            plt.title(name, size=14)

        colors = np.array(list(islice(cycle(['#377eb8', '#ff7f00', '#4daf4a',
                                             '#f781bf', '#a65628', '#984ea3',
                                             '#999999', '#e41a1c', '#dede00']),
                                      int(max(y_pred) + 1))))
        axes[i][j].scatter(X[:, 0], X[:, 1], s=10, color=colors[y_pred])

        axes[i][j].text(.99, .01, ('%.2fs' % (t1 - t0)).lstrip('0'), transform=plt.gca().transAxes, size=13,
                 horizontalalignment='right')
        axes[i][j].set_title(f"{name}")
        plt.xlim(-2.5, 2.5)
        plt.ylim(-2.5, 2.5)
        plt.xticks(())
        plt.yticks(())
        plt.dist = 12

        plot_num += 1
plt.show()

# %% [markdown]
# # 觀察結果
# * noisy_moons 雜訊半月弧: 三者效果也是以 Complete 較差
# * blobs 斑點: 三者效果相似
# * no_structure 無結構: 三者效果以 Complete 較不齊整，但資料隨機分布，無法判定分類好壞
# * noisy_circles 同心圓 : 三者效果中 Complete 的效果似乎是最差
# * varied 三群 : Average 與 Ward 效果都還不錯
# * aniso 斜三群 : 三者效果也是以 Complete 較差

# %% [markdown]
# ref:
# [Comparing different clustering algorithms on toy datasets](https://scikit-learn.org/stable/auto_examples/cluster/plot_cluster_comparison.html)
